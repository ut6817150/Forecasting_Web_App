# %% [markdown]
# ## Sampling data
#
# This script applies some initial cleaning steps and splits the data into a train and test set

# %%
import numpy as np
import pandas as pd
import os
import json
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# %%
# set variables from config file
config_path = os.path.abspath('..')

with open(config_path + '\config-example.json', 'r') as f:
    config = json.load(f)

dataset_output_fname = config['DEFAULT']['dataset_output_fname']
dataset_sampled_fname = config['DEFAULT']['dataset_sampled_fname']
processing_path = config['DEFAULT']['processing_path']
dataset_fname_suffix = config['DEFAULT']['dataset_fname_suffix']

# %%
client_data = pd.read_csv(os.path.join(processing_path,dataset_output_fname) + dataset_fname_suffix, header = 0, delimiter = ',',)

# %%
client_data.head()
# Out:
#                                            EventName         StartDate  \
# 0              Developing Reading and Writing Skills  28/11/2017 00:00
# 1                Teaching Grammar: Classroom choices  13/12/2017 00:00
# 2                Teaching Grammar: Classroom choices  13/12/2017 00:00
# 3  Academic vocabulary: what do students need to ...  19/04/2018 00:00
# 4                          Researching the classroom  14/11/2018 00:00
#
#          EventType BookingReference AttendeeReference  GroupSize  \
# 0  Others, Group 1          B462687           A514297          1
# 1  Others, Group 1          B462689           A514299          1
# 2  Others, Group 1          B467150           A519135          1
# 3  Others, Group 2          B533234           A588469          1
# 4  Others, Group 4          B604614           A662691          1
#
#   IsLeadAttendee  AttendeeGrossCost  EventId BookingStatus AttendeeType  \
# 0           True                0.0    14983    Registered     Attendee
# 1           True                0.0    14960    Registered     Attendee
# 2           True                0.0    14960    Registered     Attendee
# 3           True                0.0    15893    Registered     Attendee
# 4           True                0.0    17350    Registered     Attendee
#
#   TicketType StatusCreatedDate  ClientId
# 0        NaN  11/11/2017 09:15     153.0
# 1        NaN  11/11/2017 09:18     153.0
# 2        NaN  22/11/2017 17:02     153.0
# 3        NaN  11/04/2018 13:38     153.0
# 4        NaN  15/10/2018 14:33     153.0

# %%
client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658446 entries, 0 to 658445
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   EventName          658446 non-null  object
#  1   StartDate          658446 non-null  object
#  2   EventType          655202 non-null  object
#  3   BookingReference   658446 non-null  object
#  4   AttendeeReference  658446 non-null  object
#  5   GroupSize          658446 non-null  int64
#  6   IsLeadAttendee     658446 non-null  object
#  7   AttendeeGrossCost  658446 non-null  float64
#  8   EventId            658446 non-null  int64
#  9   BookingStatus      658442 non-null  object
#  10  AttendeeType       658446 non-null  object
#  11  TicketType         166470 non-null  object
#  12  StatusCreatedDate  658442 non-null  object
#  13  ClientId           658440 non-null  float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.3+ MB

# %% [markdown]
# ### Imputing missing values

# %% [markdown]
# For values which do not change often over time such as EventType, BookingStatus, StatusCreatedDate and ClientId  ( which are all already established), it's safe to use the data from previous inputs where available to fill the missing values in more recent inputs.

# %%
# for client_dataset
fill_columns = ['EventType','BookingStatus','StatusCreatedDate', 'ClientId']

for c in fill_columns:
    print(c)
    client_data[c] = client_data[c].fillna(method='ffill')
# Out:
# EventType
# BookingStatus
# StatusCreatedDate
# ClientId

# %%
# chekcing length of filled data
len(client_data)
# Out:
# 658446

# %%
client_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658446 entries, 0 to 658445
# Data columns (total 14 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   EventName          658446 non-null  object
#  1   StartDate          658446 non-null  object
#  2   EventType          658446 non-null  object
#  3   BookingReference   658446 non-null  object
#  4   AttendeeReference  658446 non-null  object
#  5   GroupSize          658446 non-null  int64
#  6   IsLeadAttendee     658446 non-null  object
#  7   AttendeeGrossCost  658446 non-null  float64
#  8   EventId            658446 non-null  int64
#  9   BookingStatus      658446 non-null  object
#  10  AttendeeType       658446 non-null  object
#  11  TicketType         166470 non-null  object
#  12  StatusCreatedDate  658446 non-null  object
#  13  ClientId           658446 non-null  float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 70.3+ MB

# %% [markdown]
# ### Clean up

# %%
client_data.reset_index(drop=True)
# Out:
#                                                 EventName         StartDate  \
# 0                   Developing Reading and Writing Skills  28/11/2017 00:00
# 1                     Teaching Grammar: Classroom choices  13/12/2017 00:00
# 2                     Teaching Grammar: Classroom choices  13/12/2017 00:00
# 3       Academic vocabulary: what do students need to ...  19/04/2018 00:00
# 4                               Researching the classroom  14/11/2018 00:00
# ...                                                   ...               ...
# 658441  Corruption and Standard in British Politics: T...  20/07/2022 17:00
# 658442  Johanna of Austria (1547-1578) – An Austrian A...  18/07/2022 18:00
# 658443                              The Future of History  15/07/2022 18:00
# 658444  Media and Democracy in India: An Insider’s Per...  14/07/2022 10:00
# 658445  Johanna of Austria (1547-1578) – An Austrian A...  18/07/2022 18:00
#
#               EventType BookingReference AttendeeReference  GroupSize  \
# 0       Others, Group 1          B462687           A514297          1
# 1       Others, Group 1          B462689           A514299          1
# 2       Others, Group 1          B467150           A519135          1
# 3       Others, Group 2          B533234           A588469          1
# 4       Others, Group 4          B604614           A662691          1
# ...                 ...              ...               ...        ...
# 658441     Other Events       IHR1106055          A1178476          1
# 658442          Seminar         B1106057          A1178478          1
# 658443          Lecture       IHR1106063          A1178485          1
# 658444          Seminar         B1106065          A1178487          1
# 658445          Seminar         B1106070          A1178492          1
#
#        IsLeadAttendee  AttendeeGrossCost  EventId BookingStatus AttendeeType  \
# 0                True                0.0    14983    Registered     Attendee
# 1                True                0.0    14960    Registered     Attendee
# 2                True                0.0    14960    Registered     Attendee
# 3                True                0.0    15893    Registered     Attendee
# 4                True                0.0    17350    Registered     Attendee
# ...               ...                ...      ...           ...          ...
# 658441           True                0.0    26428     Attending     Attendee
# 658442           True                0.0    26342     Attending     Attendee
# 658443           True                0.0    26117     Attending     Attendee
# 658444           True                0.0    26430     Attending     Attendee
# 658445           True                0.0    26342     Attending     Attendee
#
#        TicketType StatusCreatedDate  ClientId
# 0             NaN  11/11/2017 09:15     153.0
# 1             NaN  11/11/2017 09:18     153.0
# 2             NaN  22/11/2017 17:02     153.0
# 3             NaN  11/04/2018 13:38     153.0
# 4             NaN  15/10/2018 14:33     153.0
# ...           ...               ...       ...
# 658441   Standard  12/07/2022 10:04     219.0
# 658442   Standard  12/07/2022 10:31     219.0
# 658443   Standard  12/07/2022 11:16     219.0
# 658444   Standard  12/07/2022 11:42     219.0
# 658445   Standard  12/07/2022 12:36     219.0
#
# [658446 rows x 14 columns]

# %%
# Replacing values in columns 

replacement_dict = {'IsLeadAttendee': {r'^Registered$':'True',0:'False'},'BookingStatus':{r'^Registered$':'Attending', 0: 'Cancelled'},
                    'AttendeeType':{r'^Day 1. 24th June 2022$':'Attendee',2020: 'Attendee'}}

client_data_cleaned = client_data.replace(replacement_dict,regex=True)

# %% [markdown]
# ### Export Data

# %%
# export
client_data_cleaned.to_csv(os.path.join(processing_path,dataset_sampled_fname) + dataset_fname_suffix,index = False)
